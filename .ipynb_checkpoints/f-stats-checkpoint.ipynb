# %%
import pandas as pd
df = pd.read_csv("csv/2019-by-clinic.csv")
df.head()
# Out:
#    OrderID                    CurrentClinicName1  \
# 0        1      ART FERTILITY PROGRAM OF ALABAMA
# 1        2   UNIVERSITY OF ALABAMA AT BIRMINGHAM
# 2        3         ALABAMA FERTILITY SPECIALISTS
# 3        4  FERTILITY INSTITUTE OF NORTH ALABAMA
# 4        5      CENTER FOR REPRODUCTIVE MEDICINE
#
#                            CurrentClinicName2 CurrentClinicCity  \
# 0                                         NaN        BIRMINGHAM
# 1  REPRODUCTIVE ENDOCRINOLOGY AND INFERTILITY        BIRMINGHAM
# 2                                         NaN          HOMEWOOD
# 3                                         NaN        HUNTSVILLE
# 4                                         NaN            MOBILE
#
#   CurrentClinicState          MedicalDirector ND_NumIntentRet1  \
# 0            ALABAMA   Michael C Allemand, MD              134
# 1            ALABAMA       Deidre D. Gunn, MD               44
# 2            ALABAMA       Mamie R McLean, MD              117
# 3            ALABAMA      Brett Davenport, MD                0
# 4            ALABAMA  George T. Koulianos, MD               78
#
#   ND_NumIntentRet2 ND_NumIntentRet3 ND_NumIntentRet4  ...  \
# 0               54               35               12  ...
# 1               13               10                *  ...
# 2               46               30               22  ...
# 3                0                0                0  ...
# 4               45               43               13  ...
#
#   DonatedEmbryoService EmbryoCryoService EggCryoService GestCarrierService  \
# 0                  Yes               Yes            Yes                Yes
# 1                  Yes               Yes            Yes                Yes
# 2                   No               Yes            Yes                Yes
# 3                   No               Yes            Yes                Yes
# 4                  Yes               Yes            Yes                Yes
#
#   SARTmember LabAccred NumResearch CurrentStateAbbrev  Geo Dive in?
# 0        Yes       Yes           0                 AL  NaN      NaN
# 1        Yes       Yes           0                 AL  NaN      NaN
# 2        Yes       Yes           0                 AL  NaN      NaN
# 3         No   Pending           0                 AL  NaN      NaN
# 4        Yes       Yes           0                 AL  NaN      NaN
#
# [5 rows x 142 columns]

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="f-stats")

city="Pasadena"
state="California"
loc = geolocator.geocode(city+','+state)
print("latitude is :-" ,loc.latitude,"\nlongtitude is:-" ,loc.longitude)
loc_point = tuple(loc.point)
print("\npoint is",loc_point)
# Out:
# latitude is :- 34.1476452
# longtitude is:- -118.1444779
#
# point is (34.1476452, -118.1444779, 0.0)

# %%
df['full_address'] = df.CurrentClinicCity + "," + df.CurrentClinicState
df.full_address.head()
# Out:
# 0    BIRMINGHAM,ALABAMA
# 1    BIRMINGHAM,ALABAMA
# 2      HOMEWOOD,ALABAMA
# 3    HUNTSVILLE,ALABAMA
# 4        MOBILE,ALABAMA
# Name: full_address, dtype: object

# %%
df['gcode'] = df.full_address.apply(geolocator.geocode)
df.gcode.head()
# Out:
# 0    (Birmingham, Jefferson County, Alabama, United...
# 1    (Birmingham, Jefferson County, Alabama, United...
# 2    (Homewood, Jefferson County, Alabama, United S...
# 3    (Huntsville, Madison County, Alabama, United S...
# 4    (Mobile, Mobile County, Alabama, United States...
# Name: gcode, dtype: object

# %%
df['point'] = df['gcode'].apply(lambda gcode: tuple(gcode.point) if gcode else None)
df.point
# Out:
# 0      (33.5206824, -86.8024326, 0.0)
# 1      (33.5206824, -86.8024326, 0.0)
# 2      (33.4717732, -86.8008228, 0.0)
# 3       (34.729847, -86.5859011, 0.0)
# 4      (30.6943566, -88.0430541, 0.0)
#                     ...
# 443    (43.1790768, -88.1170784, 0.0)
# 444    (43.0962919, -89.5119565, 0.0)
# 445    (43.0962919, -89.5119565, 0.0)
# 446     (43.0349931, -87.922497, 0.0)
# 447    (43.0166806, -88.0070315, 0.0)
# Name: point, Length: 448, dtype: object

# %%
df[df['gcode'].isnull()]
# Out:
# Empty DataFrame
# Columns: [OrderID, CurrentClinicName1, CurrentClinicName2, CurrentClinicCity, CurrentClinicState, MedicalDirector, ND_NumIntentRet1, ND_NumIntentRet2, ND_NumIntentRet3, ND_NumIntentRet4, ND_IntentRetLB1, ND_IntentRetLB2, ND_IntentRetLB3, ND_IntentRetLB4, ND_IntentRetSingleLB1, ND_IntentRetSingleLB2, ND_IntentRetSingleLB3, ND_IntentRetSingleLB4, ND_NumRetrieve1, ND_NumRetrieve2, ND_NumRetrieve3, ND_NumRetrieve4, ND_RetrieveLB1, ND_RetrieveLB2, ND_RetrieveLB3, ND_RetrieveLB4, ND_RetrieveSingleLB1, ND_RetrieveSingleLB2, ND_RetrieveSingleLB3, ND_RetrieveSingleLB4, ND_NumTrans1, ND_NumTrans2, ND_NumTrans3, ND_NumTrans4, ND_TransLB1, ND_TransLB2, ND_TransLB3, ND_TransLB4, ND_TransSingleLB1, ND_TransSingleLB2, ND_TransSingleLB3, ND_TransSingleLB4, ND_IntentRetPerLB1, ND_IntentRetPerLB2, ND_IntentRetPerLB3, ND_IntentRetPerLB4, NewND_1IntentRetLB1, NewND_1IntentRetLB2, NewND_1IntentRetLB3, NewND_1IntentRetLB4, NewND_2IntentRetLB1, NewND_2IntentRetLB2, NewND_2IntentRetLB3, NewND_2IntentRetLB4, NewND_AllIntentRetLB1, NewND_AllIntentRetLB2, NewND_AllIntentRetLB3, NewND_AllIntentRetLB4, NewND_IntentRetPerNew1, NewND_IntentRetPerNew2, NewND_IntentRetPerNew3, NewND_IntentRetPerNew4, NewND_TransPerIntentRet1, NewND_TransPerIntentRet2, NewND_TransPerIntentRet3, NewND_TransPerIntentRet4, Donor_NumTrans1, Donor_NumTrans2, Donor_NumTrans3, Donor_NumTrans4, Donor_TransLB1, Donor_TransLB2, Donor_TransLB3, Donor_TransLB4, Donor_TranSingleLB1, Donor_TranSingleLB2, Donor_TranSingleLB3, Donor_TranSingleLB4, TotNumCycles1, TotNumCycles2, TotNumCycles3, TotNumCycles4, TotNumCyclesAll, CycleCancel1, CycleCancel2, CycleCancel3, CycleCancel4, CycleCancelAll, CycleStop1, CycleStop2, CycleStop3, CycleStop4, CycleStopAll, CycleFertPres1, CycleFertPres2, CycleFertPres3, CycleFertPres4, CycleFertPresAll, TransCarrier1, TransCarrier2, ...]
# Index: []
#
# [0 rows x 145 columns]

# %%
df[['lat','lon','altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)
df.head()
# Out:
#    OrderID                    CurrentClinicName1  \
# 0        1      ART FERTILITY PROGRAM OF ALABAMA
# 1        2   UNIVERSITY OF ALABAMA AT BIRMINGHAM
# 2        3         ALABAMA FERTILITY SPECIALISTS
# 3        4  FERTILITY INSTITUTE OF NORTH ALABAMA
# 4        5      CENTER FOR REPRODUCTIVE MEDICINE
#
#                            CurrentClinicName2 CurrentClinicCity  \
# 0                                         NaN        BIRMINGHAM
# 1  REPRODUCTIVE ENDOCRINOLOGY AND INFERTILITY        BIRMINGHAM
# 2                                         NaN          HOMEWOOD
# 3                                         NaN        HUNTSVILLE
# 4                                         NaN            MOBILE
#
#   CurrentClinicState          MedicalDirector ND_NumIntentRet1  \
# 0            ALABAMA   Michael C Allemand, MD              134
# 1            ALABAMA       Deidre D. Gunn, MD               44
# 2            ALABAMA       Mamie R McLean, MD              117
# 3            ALABAMA      Brett Davenport, MD                0
# 4            ALABAMA  George T. Koulianos, MD               78
#
#   ND_NumIntentRet2 ND_NumIntentRet3 ND_NumIntentRet4  ... NumResearch  \
# 0               54               35               12  ...           0
# 1               13               10                *  ...           0
# 2               46               30               22  ...           0
# 3                0                0                0  ...           0
# 4               45               43               13  ...           0
#
#   CurrentStateAbbrev  Geo Dive in?        full_address  \
# 0                 AL  NaN      NaN  BIRMINGHAM,ALABAMA
# 1                 AL  NaN      NaN  BIRMINGHAM,ALABAMA
# 2                 AL  NaN      NaN    HOMEWOOD,ALABAMA
# 3                 AL  NaN      NaN  HUNTSVILLE,ALABAMA
# 4                 AL  NaN      NaN      MOBILE,ALABAMA
#
#                                                gcode  \
# 0  (Birmingham, Jefferson County, Alabama, United...
# 1  (Birmingham, Jefferson County, Alabama, United...
# 2  (Homewood, Jefferson County, Alabama, United S...
# 3  (Huntsville, Madison County, Alabama, United S...
# 4  (Mobile, Mobile County, Alabama, United States...
#
#                             point        lat        lon altitude
# 0  (33.5206824, -86.8024326, 0.0)  33.520682 -86.802433      0.0
# 1  (33.5206824, -86.8024326, 0.0)  33.520682 -86.802433      0.0
# 2  (33.4717732, -86.8008228, 0.0)  33.471773 -86.800823      0.0
# 3   (34.729847, -86.5859011, 0.0)  34.729847 -86.585901      0.0
# 4  (30.6943566, -88.0430541, 0.0)  30.694357 -88.043054      0.0
#
# [5 rows x 148 columns]

# %%
from geopy import distance

df['distance'] = df.apply(lambda x: distance.distance(loc_point, x['point']).miles, axis=1)
df.distance
# Out:
# 0      1796.078641
# 1      1796.078641
# 2      1796.770888
# 3      1795.259769
# 4      1768.849660
#           ...
# 443    1727.810897
# 444    1657.585739
# 445    1657.585739
# 446    1735.627175
# 447    1731.187057
# Name: distance, Length: 448, dtype: float64

# %%
closest = df.nsmallest(5,'distance')
closest
# Out:
#     OrderID             CurrentClinicName1 CurrentClinicName2  \
# 59       60                  HRC FERTILITY                NaN
# 60       61    UNITY FERTILITY CENTER, LLC                NaN
# 32       33                 CARE FERTILITY                NaN
# 33       34      KATHLEEN KORNAFEL, MD PHD                NaN
# 40       41  CALIFORNIA FERTILITY PARTNERS                NaN
#
#    CurrentClinicCity CurrentClinicState             MedicalDirector  \
# 59          PASADENA         CALIFORNIA          John G. Wilcox, MD
# 60          PASADENA         CALIFORNIA      Chun-Yeh Wang, MD, PhD
# 32          GLENDALE         CALIFORNIA           Rudy Quintero, MD
# 33          GLENDALE         CALIFORNIA  KATHLEEN KORNAFEL, MD, PhD
# 40       LOS ANGELES         CALIFORNIA        Richard P. Marrs, MD
#
#    ND_NumIntentRet1 ND_NumIntentRet2 ND_NumIntentRet3 ND_NumIntentRet4  ...  \
# 59              602              442              419              453  ...
# 60               10                *                7               14  ...
# 32               71               39               50               26  ...
# 33                0                0                0                0  ...
# 40               70              117              146              245  ...
#
#    CurrentStateAbbrev   Geo Dive in?            full_address  \
# 59                 CA  True      NaN     PASADENA,CALIFORNIA
# 60                 CA  True    False     PASADENA,CALIFORNIA
# 32                 CA  True      NaN     GLENDALE,CALIFORNIA
# 33                 CA  True    False     GLENDALE,CALIFORNIA
# 40                 CA  True      NaN  LOS ANGELES,CALIFORNIA
#
#                                                 gcode  \
# 59  (Pasadena, California, United States, (34.1476...
# 60  (Pasadena, California, United States, (34.1476...
# 32  (Glendale, California, United States, (34.1469...
# 33  (Glendale, California, United States, (34.1469...
# 40  (Los Angeles, California, United States, (34.0...
#
#                               point        lat         lon altitude  distance
# 59  (34.1476452, -118.1444779, 0.0)  34.147645 -118.144478      0.0  0.000000
# 60  (34.1476452, -118.1444779, 0.0)  34.147645 -118.144478      0.0  0.000000
# 32  (34.1469416, -118.2478471, 0.0)  34.146942 -118.247847      0.0  5.923871
# 33  (34.1469416, -118.2478471, 0.0)  34.146942 -118.247847      0.0  5.923871
# 40   (34.0536909, -118.242766, 0.0)  34.053691 -118.242766      0.0  8.584634
#
# [5 rows x 149 columns]

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=closest[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)
# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in closest.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                      popup = r['Name'],
                      tooltip=r['Name'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-2ff547bd7de6> in <module>
#       1 # import the library and its Marker clusterization service
# ----> 2 import folium
#       3 from folium.plugins import MarkerCluster
#       4 # Create a map object and center it to the avarage coordinates to m
#       5 m = folium.Map(location=closest[["lat", "lon"]].mean().to_list(), zoom_start=2)
#
# ModuleNotFoundError: No module named 'folium'
